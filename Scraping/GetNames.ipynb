# %%
import requests
from bs4 import BeautifulSoup
from lxml import etree

# %%
# Looking to get all the pokemon names from this link
NAMES_URL = "https://bulbapedia.bulbagarden.net/wiki/List_of_Pok%C3%A9mon_by_National_Pok%C3%A9dex_number"

response = requests.get(NAMES_URL)
soup = BeautifulSoup(response.content, "html.parser")

# HTML element wanting to find
# /html/body/div[2]/div[1]/div[1]/div[6]/div[4]/div/table[2]/tbody/tr[2]/td[3]/a
# /html/body/div[2]/div[1]/div[1]/div[6]/div[4]/div/table[2]/tbody/tr[3]/td[3]/a

# /html/body/div[2]/div[1]/div[1]/div[6]/div[4]/div/table[3]/tbody/tr[2]/td[3]/a

# %%
class Pokemon:
    def __init__(self, pokedex_id="", name="", type="", top_image="", abilities=[], hidden_abilities="", gender_ratio="", evolution=[], generation_introducted="", catch_rate="", egg_group="", height="", weight="", EV_yield="", stats=[], generation_entries=[]):
        self.pokedex_id= pokedex_id
        self.name = name
        self.type = type
        self.top_image = top_image
        self.abilities = abilities
        self.hidden_abilities = hidden_abilities
        self.gender_ratio = gender_ratio
        self.evolution = evolution
        self.generation_introduced = generation_introducted
        self.catch_rate = catch_rate 
        self.egg_group = egg_group
        self.height = height
        self.weight = weight
        self.EV_yield = EV_yield
        self.stats = stats 
        self.generation_entries = generation_entries

    def __str__(self):
        return f"{self.pokedex_id} | {self.name}"

# %%
# Starting a list to hold all the pokemon data
pokedex_data = list()

# Look for all tbody elements
tbody_elements = soup.find_all("tbody")

# Noticed that we need 9 generations and the first tbody is referring to a different box of information
for i in range(1, 10):

    # print("----" * 20)
    # print(tbody_elements[i])

    # Finding all the rows in the tbody
    tr_elements = tbody_elements[i].find_all("tr")

    # Looping through all the rows
    for tr in tr_elements:
        td_elements = tr.find_all("td")

        if len(td_elements) != 0:
            # print(td_elements[0])
            # Result:
            # <td rowspan="1" style="font-family:monospace,monospace">#0001</td>

            # print(td_elements[2])
            # Result: 
            # <td><a href="/wiki/Bulbasaur_(Pok%C3%A9mon)" title="Bulbasaur (Pokémon)">Bulbasaur</a><br/><small></small></td>

            pokemon_id = td_elements[0].text
            pokemon_name = td_elements[2].text

            if (pokemon_id != "") & (pokemon_name != ""):
                pokedex_data.append(Pokemon(pokedex_id=pokemon_id, name=pokemon_name))

# %%
print(len(pokedex_data))

for data in pokedex_data:
    print(data)

# Have collected all the pokemon names and id #
# Out:
# 1015
# #0001 | Bulbasaur
# #0002 | Ivysaur
# #0003 | Venusaur
# #0004 | Charmander
# #0005 | Charmeleon
# #0006 | Charizard
# #0007 | Squirtle
# #0008 | Wartortle
# #0009 | Blastoise
# #0010 | Caterpie
# #0011 | Metapod
# #0012 | Butterfree
# #0013 | Weedle
# #0014 | Kakuna
# #0015 | Beedrill
# #0016 | Pidgey
# #0017 | Pidgeotto
# #0018 | Pidgeot
# #0019 | Rattata
# #0020 | Raticate
# #0021 | Spearow
# #0022 | Fearow
# #0023 | Ekans
# #0024 | Arbok
# #0025 | Pikachu
# #0026 | Raichu
# #0027 | Sandshrew
# #0028 | Sandslash
# #0029 | Nidoran♀
# #0030 | Nidorina
# #0031 | Nidoqueen
# #0032 | Nidoran♂
# #0033 | Nidorino
# #0034 | Nidoking
# #0035 | Clefairy
# #0036 | Clefable
# #0037 | Vulpix
# #0038 | Ninetales
# #0039 | Jigglypuff
# #0040 | Wigglytuff
# #0041 | Zubat
# #0042 | Golbat
# #0043 | Oddish
# #0044 | Gloom
# #0045 | Vileplume
# #0046 | Paras
# #0047 | Parasect
# #0048 | Venonat
# #0049 | Venomoth
# #0050 | Diglett
# #0051 | Dugtrio
# #0052 | Meowth
# #0053 | Persian
# ...

# %%
# Insert these names into a base URL to collect the rest of the data
BASE_SEARCH_URL = "https://bulbapedia.bulbagarden.net/wiki/"

for pokemon in pokedex_data:
    response = requests.get(BASE_SEARCH_URL + pokemon.name)
    soup = BeautifulSoup(response.content, "html.parser")

    title_element = soup.find('a', string='Type')
    print(title_element)
    parent_b = title_element.find_parent('b')

    if parent_b:
        table = parent_b.find_next_sibling('table')
        # print(table)

        if table:
            links = table.find_all('a')
            print(f'Pokemon Name: {pokemon.name}')

            for link in links:
                if link.text != "Unknown":
                    pokemon.abilities.append(link.text)
                    print(link.text)
        else:
            print('Parent table element not found')
    else:
        print('Title element not found')
# Out:
# <a href="/wiki/Type" title="Type"><span style="color:#000;">Type</span></a>
# Pokemon Name: Bulbasaur
# Grass
# Poison
# <a href="/wiki/Type" title="Type"><span style="color:#000;">Type</span></a>
# Pokemon Name: Ivysaur
# Grass
# Poison
# <a href="/wiki/Type" title="Type"><span style="color:#000;">Type</span></a>
# Pokemon Name: Venusaur
# Grass
# Poison
# <a href="/wiki/Type" title="Type"><span style="color:#000;">Type</span></a>
# Pokemon Name: Charmander
# Fire
# <a href="/wiki/Type" title="Type"><span style="color:#000;">Type</span></a>
# Pokemon Name: Charmeleon
# Fire
# <a href="/wiki/Type" title="Type"><span style="color:#000;">Type</span></a>
# Title element not found

# %%
# Testing how to collect it all on a single pokemon first

VENUSAUR_URL = "https://m.bulbapedia.bulbagarden.net/wiki/Venusaur_(Pok%C3%A9mon)"
CHARIZARD_URL = "https://bulbapedia.bulbagarden.net/wiki/Charizard_(Pok%C3%A9mon)"
KYUREM_URL = "https://m.bulbapedia.bulbagarden.net/wiki/Kyurem_(Pok%C3%A9mon)"

response = requests.get(KYUREM_URL)
soup = BeautifulSoup(response.content, "html.parser")

# Just to double check we have the correct pokemon id
# pokemon_id = soup.find_all(title="List of Pokémon by National Pokédex number")[1].text



# dom = etree.HTML(str(soup))
# print(dom.xpath('//*[@id="mf-section-0"]/table[2]/tbody/tr[3]/td/table')[0][0][0][0])

# print(dom.xpath('//*[@id="mw-content-text"]/div/table[2]/tbody/tr[2]/td/table/tbody/tr/td[1]/table/tbody/tr/td[1]/a/span/b')[0].text)
# print(dom.xpath('//*[@id="mw-content-text"]/div/table[2]/tbody/tr[2]/td/table/tbody/tr/td[1]/table/tbody/tr/td[2]/a/span/b')[0].text)

# '//*[@id="mf-section-0"]/table[2]/tbody/tr[2]/td/table/tbody/tr/td[1]/table/tbody/tr/td[1]/a/span/b'
# '//*[@id="mf-section-0"]/table[2]/tbody/tr[2]/td/table/tbody/tr/td[1]/table/tbody/tr/td[2]/a/span/b'

#tbody_elements = soup.table_a("tbody")
#print(tbody_elements[0])
#print(len(tbody_elements))
# Out:
# <Element td at 0x244f343b640>

# %%
# Testing how to collect it all on a single pokemon first

VENUSAUR_URL = "https://m.bulbapedia.bulbagarden.net/wiki/Venusaur_(Pok%C3%A9mon)"
CHARIZARD_URL = "https://bulbapedia.bulbagarden.net/wiki/Charizard_(Pok%C3%A9mon)"
KYUREM_URL = "https://m.bulbapedia.bulbagarden.net/wiki/Kyurem_(Pok%C3%A9mon)"
RATATA_URL = 'https://bulbapedia.bulbagarden.net/wiki/Rattata_(Pok%C3%A9mon)'

name = "Mr. Mine"
BASE_SEARCH_URL = "https://bulbapedia.bulbagarden.net/wiki/"

response = requests.get(BASE_SEARCH_URL + name.replace(" ", "_"))
soup = BeautifulSoup(response.content, "html.parser")

print(soup.prettify())

# title_element = soup.find('a', string='Types')
# print(title_element)
# parent_b = title_element.find_parent('b')
# print(parent_b)

title_element = soup.find('a', title="Type")
parent_b = title_element.find_parent('b')

if parent_b:
    table_main = parent_b.find_next_sibling('table')
    # print(table)
    tables = table_main.find_all('table')
    
    for table in tables:

        small = table.find_next_sibling('small')

        if small.text == "Rattata":
            links = table.find_all('a')

            for link in links:
                if link.text != "Unknown":
                    print(link.text)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Mr. Mine - Bulbapedia, the community-driven Pokémon encyclopedia
#   </title>
#   <script>
# ...
